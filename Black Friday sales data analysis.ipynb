# %%
import pandas as pd

# %%
dt=pd.read_csv('Blackfriday_sales.csv.csv')
dt
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
dt.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
dt.dropna().isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
del dt['Product_Category_2']
del dt['Product_Category_3']

# %%
dt
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
dt['User_ID'].nunique()
# Out:
# 5891

# %%
dt['Product_ID'].nunique()
# Out:
# 3631

# %%
dt['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
dt['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
dt['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
dt['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
dt['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
dt['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
dt['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19], dtype=int64)

# %%
dt['Purchase'].sum()/len(dt['Purchase'])
# Out:
# 9263.968712959126

# %%
for column in dt.columns:
    print(column,dt[column].nunique())
# Out:
# User_ID 5891
# Product_ID 3631
# Gender 2
# Age 7
# Occupation 21
# City_Category 3
# Stay_In_Current_City_Years 5
# Marital_Status 2
# Product_Category_1 20
# Purchase 18105

# %%
len(dt[dt['Gender']=='M']),len(dt[dt['Gender']=='F'])
# Out:
# (414259, 135809)

# %%
data=pd.DataFrame({'Ratio':[len(dt[dt['Gender']=='M']),len(dt[dt['Gender']=='F'])]},index=['Male','Female'])

# %%
data
# Out:
#          Ratio
# Male    414259
# Female  135809

# %%
data.plot.pie(y='Ratio',figsize=(8,8),autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='Ratio'>

# %%
dt.groupby('Gender').size().plot(kind='pie',autopct='%.1f',figsize=(8,8),title='Total gender size' )
# Out:
# <AxesSubplot:title={'center':'Total gender size'}, ylabel='None'>

# %%
dt.groupby('Gender').size().plot(kind='bar' )
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
dt.groupby('Gender').sum()['Purchase'].plot(kind='pie',figsize=(6,6),autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
dt.groupby('Gender').mean()['Purchase'].plot(kind='pie',figsize=(6,6),autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
dt.groupby('Age').size().plot(kind='bar',figsize=(12,5),title='Purchase Distribution by age')
# Out:
# <AxesSubplot:title={'center':'Purchase Distribution by age'}, xlabel='Age'>

# %%
lst=[]
for i in dt['Age'].unique():
    lst.append([i,dt[dt['Age']==i]['Product_ID'].nunique()])
data=pd.DataFrame(lst,columns=['Age','Products'])

# %%
data.plot.bar(x ='Age',figsize=(8,6))
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
dt.groupby('Age').sum()
# Out:
#             User_ID  Occupation  Marital_Status  Product_Category_1  \
# Age
# 0-17    15143112813      132309               0               76775
# 18-25   99939196632      671348           21116              509371
# 26-35  220270500414     1734073           86291             1166945
# 36-45  110350311441      972225           43636              604438
# 46-50   45846804203      389239           33011              262424
# 51-55   38615925320      339198           27662              222313
# 55+     21568218459      204346           13621              130450
#
#          Purchase
# Age
# 0-17    134913183
# 18-25   913848675
# 26-35  2031770578
# 36-45  1026569884
# 46-50   420843403
# 51-55   367099644
# 55+     200767375

# %%
dt.groupby('Age').sum().plot(kind='bar',figsize=(12,5),title='Amount spent by age')
# Out:
# <AxesSubplot:title={'center':'Amount spent by age'}, xlabel='Age'>

# %%
dt.groupby('Age').mean()
# Out:
#             User_ID  Occupation  Marital_Status  Product_Category_1  \
# Age
# 0-17   1.002722e+06    8.761025        0.000000            5.083764
# 18-25  1.002801e+06    6.736384        0.211880            5.111088
# 26-35  1.003113e+06    7.896975        0.392970            5.314272
# 36-45  1.003066e+06    8.837365        0.396644            5.494242
# 46-50  1.003190e+06    8.517078        0.722326            5.742194
# 51-55  1.002985e+06    8.810109        0.718475            5.774214
# 55+    1.002986e+06    9.502697        0.633417            6.066313
#
#           Purchase
# Age
# 0-17   8933.464640
# 18-25  9169.663606
# 26-35  9252.690633
# 36-45  9331.350695
# 46-50  9208.625697
# 51-55  9534.808031
# 55+    9336.280459

# %%
dt.groupby('Age').sum().plot(kind='bar',figsize=(12,5),title='Amount spent by age')
# Out:
# <AxesSubplot:title={'center':'Amount spent by age'}, xlabel='Age'>

# %%
dt.groupby('Age').sum()['Purchase'].plot(kind= 'pie',figsize=(8,6),autopct='%0.1f')
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
dt.groupby('Age').mean()['Purchase'].plot(kind= 'pie',figsize=(8,6),autopct='%0.1f')
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
dt.groupby('Marital_Status').size().plot(kind= 'pie',figsize=(8,6),autopct='%0.1f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
dt.groupby('Gender').size().plot(kind= 'pie',figsize=(8,6),autopct='%0.1f')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# ## For multi-column analysis seaborn library is used

# %%
import seaborn as sns

# %%
dt
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Age',hue='Gender',data=dt)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Gender',hue='Age',data=dt)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.countplot(x='Gender',hue='Marital_Status',data=dt)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.countplot(x='Marital_Status',hue='Gender',data=dt)
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x=dt['City_Category'])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
dt.groupby('City_Category').size().plot(kind='pie',autopct='%0.1f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
sns.countplot(x=dt['City_Category'],hue='Age',data=dt)
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x=dt['Age'],hue='City_Category',data=dt)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
dt.groupby('City_Category').sum()['Purchase'].plot(kind='pie',autopct='%0.1f')
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
dt.groupby('City_Category').mean()['Purchase'].plot(kind='pie',autopct='%0.1f')
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
dt
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
sns.countplot(x=dt['Stay_In_Current_City_Years'])
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Gender',data=dt)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Marital_Status',data=dt)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='City_Category',data=dt)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Age',data=dt)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
dt.groupby('Stay_In_Current_City_Years').size().plot(kind='pie',autopct='%0.1f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
dt.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years'>

# %%
dt.groupby('Stay_In_Current_City_Years').mean()['Purchase'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x=dt['Occupation'])
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
dt.groupby(["Occupation"]).size().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
dt.groupby(["Occupation"]).sum()['Purchase'].sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
dt.groupby(["Occupation"]).mean()['Purchase'].sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
sns.countplot(x='Occupation',hue='Marital_Status',data=dt)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
dt.groupby(['Occupation']).nunique()['Product_ID'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
dt.groupby(['Occupation']).nunique()['Product_ID'].sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
dt.groupby(['Product_Category_1']).size().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product_Category_1'>

# %%
dt
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
dt.groupby(['Product_Category_1']).mean()['Purchase'].sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product_Category_1'>

# %%
dt.groupby('Product_ID').sum()['Purchase'].nlargest(10).sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product_ID'>

# %%
dt
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
l=[]
for i in range(len(dt)):
    l.append(dt['Gender'][i]+"_"+str(dt['Marital_Status'][i]))
dt['MaritalGender']=l

# %%
dt.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   MaritalGender
# 0           F_0
# 1           F_0
# 2           F_0
# 3           F_0
# 4           M_0

# %%
sns.countplot(x=dt['MaritalGender'])
# Out:
# <AxesSubplot:xlabel='MaritalGender', ylabel='count'>

# %%
sns.countplot(x=dt['Age'],hue=dt['MaritalGender'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x=dt['Product_Category_1'],hue=dt['MaritalGender'])
sns.set({'figure.figsize':(12,8)})

# %%
sns.countplot(x=dt['Stay_In_Current_City_Years'],hue=dt['MaritalGender'])
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x=dt['City_Category'],hue=dt['MaritalGender'])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>
